# %% [markdown]
# # Chapter 8: Integration Techniques, L'H&Ocirc;pital's Rule, and Improper Integrals

# %% [markdown]
# ### Section 4.2:
#
# ### Section Objectives:
# ##### Objective 1:
# ##### Objective 2:
# ##### Objective 3:

# %% [markdown]
# ##### Objective 1:

# %% [markdown]
# ##### Objective 2:

# %% [markdown]
# ##### Objective 3:

# %% [markdown]
# ##### End of Section
